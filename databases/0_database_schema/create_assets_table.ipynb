# %%
import os
import psycopg2
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv(override=True)

# Database credentials
USER = os.getenv("user")
PASSWORD = os.getenv("password")
HOST = os.getenv("host")
PORT = os.getenv("port")
DBNAME = os.getenv("dbname")

conn = None

try:
    # 1. Establish connection
    print(f"Connecting to {HOST}...")
    conn = psycopg2.connect(
        user=USER,
        password=PASSWORD,
        host=HOST,
        port=PORT,
        dbname=DBNAME
    )

    cur = conn.cursor()

    # 2. Define and execute table creation
    print("Creating 'assets' table...")
    cur.execute("""
    CREATE TABLE IF NOT EXISTS public.assets (
        ticker TEXT PRIMARY KEY,
        asset_name TEXT NOT NULL,
        asset_type TEXT,
        sector TEXT,
        exchange TEXT,
        currency TEXT,
        beta DECIMAL(10, 4),
        volatility DECIMAL(10, 4),
        max_drawdown DECIMAL(10, 4),
        risk_category TEXT,
        investment_style TEXT,
        dividend_yield DECIMAL(10, 4),
        avg_return_1y DECIMAL(10, 4),
        avg_return_3y DECIMAL(10, 4),
        avg_return_5y DECIMAL(10, 4));
    """)

    # 3. Commit changes
    conn.commit()
    print("Table created successfully.")

except Exception as e:
    print(f"Database error: {e}")

finally:
    # 4. Securely close resources
    if conn:
        cur.close()
        conn.close()
        print("Connection closed.")
# Out:
# Connecting to aws-0-eu-west-1.pooler.supabase.com...
# Creating 'assets' table...
# Table created successfully.
# Connection closed.
